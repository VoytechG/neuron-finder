# %%
# %run ground_truth_generator.py
# %matplotlib notebook

# %%
plt.imshow(filtersBinary[1])
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
eventsInFrames[:4]
# Out:
# array([array([], dtype=float64), array([158, 219, 415], dtype=uint16),
#        array([282, 371, 442], dtype=uint16),
#        array([145, 203, 579], dtype=uint16)], dtype=object)
